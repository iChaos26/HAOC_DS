# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
import statsmodels.api as sm


#kaggle_separado = csv.reader(open('/Downloads/kaggle_separado'), delimiter=",")
pd_hertz= pd.read_excel("C:\Users\logonrmlocal\Downloads\Book1.xlsx")

# %%
pd_hertz=pd_hertz.dropna()
pd_hertz.tail()
# Out:
#       Masculino  Idade  education  currentSmoker  cigsPerDay  BPMeds  \
# 4231        1.0   58.0        3.0            0.0         0.0     0.0
# 4232        1.0   68.0        1.0            0.0         0.0     0.0
# 4233        1.0   50.0        1.0            1.0         1.0     0.0
# 4234        1.0   51.0        3.0            1.0        43.0     0.0
# 4237        0.0   52.0        2.0            0.0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4231              0.0           1.0       0.0    187.0  141.0   81.0  24.96
# 4232              0.0           1.0       0.0    176.0  168.0   97.0  23.14
# 4233              0.0           1.0       0.0    313.0  179.0   92.0  25.97
# 4234              0.0           0.0       0.0    207.0  126.5   80.0  19.71
# 4237              0.0           0.0       0.0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 4231       80.0     81.0         0.0
# 4232       60.0     79.0         1.0
# 4233       66.0     86.0         1.0
# 4234       65.0     68.0         0.0
# 4237       80.0    107.0         0.0

# %%
X=pd_hertz.loc[:,['cigsPerDay']]
desvpad=11.920094 #amostral
ux=9 #hipotese nula
list_X=X.values.tolist()
n = len(list_X)
xb = np.mean(X)
desvpadb=desvpad/n**(0.5)
a = 0.05
X.describe()
# Out:
#         cigsPerDay
# count  4209.000000
# mean      9.003089
# std      11.920094
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%      20.000000
# max      70.000000

# %%
valor_p = (1-stats.norm.cdf(xb, loc=ux, scale=desvpadb))*2 # vezes 2 se for bicaudal, area de rejeição H0
print("valor-p = {0}\n".format(valor_p))

xcrit1 = stats.norm.ppf(a/2, loc=ux, scale=desvpadb)#esquerda
xcrit2 = stats.norm.ppf(1-a/2, loc=ux, scale=desvpadb)#direita

#pdf de Xb
x = np.arange(stats.norm.ppf(0.001, loc=ux, scale=desvpadb), stats.norm.ppf(0.999, loc=ux, scale=desvpadb), 0.01)
plt.plot(x, stats.norm.pdf(x, loc=ux, scale=desvpadb));

#RC1 - à esquerda
x = np.arange(stats.norm.ppf(0.001, loc=ux, scale=desvpadb), xcrit1, 0.01)
plt.fill_between(x, stats.norm.pdf(x, loc=ux, scale=desvpadb), color='red');
#RC2 - à direita
x = np.arange(xcrit2, stats.norm.ppf(0.999, loc=ux, scale=desvpadb), 0.01)
plt.fill_between(x, stats.norm.pdf(x, loc=ux, scale=desvpadb), color='red');

print("xcrit1 = {0}".format(xcrit1))
print("xcrit2 = {0}".format(xcrit2))
# Out:
# valor-p = [0.98654028]
#
# xcrit1 = 8.64116395369
# xcrit2 = 9.35883604631

# %%
X=pd_hertz.loc[:,['sysBP']]
desvpad=22.038097 #amostral
ux=132 #hipotese nula
list_X=X.values.tolist()
n = len(list_X)
xb = np.mean(X)
desvpadb=desvpad/n**(0.5)
a = 0.05
X.describe()
# Out:
#              sysBP
# count  4238.000000
# mean    132.352407
# std      22.038097
# min      83.500000
# 25%     117.000000
# 50%     128.000000
# 75%     144.000000
# max     295.000000

# %%
xcrit1 = stats.norm.ppf(1-a, loc=ux, scale=desvpadb)# direita
xcrit2 = stats.norm.ppf(a, loc=ux, scale=desvpadb)#esquerda
print("xcrit = {0}".format(xcrit1))
valor_p = (1-stats.norm.cdf(xb, loc=ux, scale=desvpadb))
print("valor-p = {0}".format(valor_p))
print ("Nível de Significância em = {0}, acima dos 2%".format((valor_p)*100))
# Out:
# xcrit = 132.556762067
# valor-p = [0.14890932]
# Nível de Significância em = [14.89093156], acima dos 2%

# %%
import statsmodels.api as sm

Y = pd_hertz.loc[:,['sysBP']]
X = pd_hertz.loc[:,['cigsPerDay']]
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sysBP   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     33.11
# Date:                Thu, 22 Aug 2019   Prob (F-statistic):           9.42e-09
# Time:                        22:01:46   Log-Likelihood:                -16487.
# No. Observations:                3656   AIC:                         3.298e+04
# Df Residuals:                    3654   BIC:                         3.299e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        133.9528      0.456    293.579      0.000     133.058     134.847
# cigsPerDay    -0.1757      0.031     -5.754      0.000      -0.236      -0.116
# ==============================================================================
# Omnibus:                      722.821   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1549.793
# Skew:                           1.143   Prob(JB):                         0.00
# Kurtosis:                       5.224   Cond. No.                         18.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
